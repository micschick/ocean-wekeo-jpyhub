# %%
from ocdb.api.OCDBApi import new_api

api = new_api()

api.config

#Out[11]: {'server_url': 'https://ocdb.eumetsat.int'}

api.set_config_param('server_url','https://ocdb.eumetsat.int')
api.login_user(username='LovedayB', password='chooseME2019ocdb')
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-3-79cf779947e5> in <module>
#       8
#       9 api.set_config_param('server_url','https://ocdb.eumetsat.int')
# ---> 10 api.login_user(username='LovedayB', password='chooseME2019ocdb')
#
# /opt/conda/lib/python3.6/site-packages/ocdb/api/OCDBApi.py in login_user(self, username, password)
#     473
#     474         request = self._make_request(f'/users/login', data=data, method="POST")
# --> 475         with urllib.request.urlopen(request) as response:
#     476             info = response.info()
#     477             if info.__contains__("Set-Cookie"):
#
# /opt/conda/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
# ...

# %%
api.find_datasets(expr="investigators:*Astrid*")
# Out:
# ---------------------------------------------------------------------------
# HTTPError                                 Traceback (most recent call last)
# <ipython-input-2-b693e283f7f7> in <module>
# ----> 1 api.find_datasets(expr="investigators:*Astrid*")
#
# /opt/conda/lib/python3.6/site-packages/ocdb/api/OCDBApi.py in find_datasets(self, **kwargs)
#     223         params = urllib.parse.urlencode(kwargs)
#     224         request = self._make_request(f'/datasets?{params}', method="GET")
# --> 225         with urllib.request.urlopen(request) as response:
#     226             return json.load(response)
#     227
#
# /opt/conda/lib/python3.6/urllib/request.py in urlopen(url, data, timeout, cafile, capath, cadefault, context)
#     221     else:
#     222         opener = _opener
# --> 223     return opener.open(url, data, timeout)
#     224
#     225 def install_opener(opener):
#
# /opt/conda/lib/python3.6/urllib/request.py in open(self, fullurl, data, timeout)
# ...
